# %% [markdown]
# <a href="https://colab.research.google.com/github/habibsifat/Prediction-of-Lysine-Glutarylation/blob/master/Glycation_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/OutputPositive.txt"

# %%
pos = '/content/drive/My Drive/Colab Notebooks/OutputPositive.txt'

# %%
#pos = 'OutputPositive.txt'
pos_seq = []
with open(pos, 'r', encoding="utf-8",errors='ignore') as f:
    for line in f:
        pos_seq.append(line.split())

# %%
len(pos_seq)
# Out:
# 6557

# %%
# !apt-get install

# %%
# !pip install propy

# %%
#from propy.GetProteinFromUniprot import GetProteinSequence as gps
import propy

# %%
neg = 'OutputNegative.txt'
neg_seq = []
with open(neg, 'r', encoding="utf-8") as f:
    for line in f:
        neg_seq.append(line.split())

# %%
len(neg_seq)

# %%
import numpy as np

# %%
print('\nPreparing the data for Positive...')
train_x = np.zeros([len(pos_seq), 15], dtype=np.int32)
train_y = np.zeros([len(pos_seq)], dtype=np.int32)
for i, pos_seq in enumerate(pos_seq):
  for t, word in enumerate(pos_seq):
    train_x[i, t] = word
  train_y[i] = 1
print('train_x shape:', train_x.shape)
print('train_y shape:', train_y.shape)

# %%
#Fasta File

pos = 'combined.txt'
pos_seq = []
with open(pos, 'r', encoding="utf-8",errors='ignore') as f:
    for line in f:
        pos_seq.append(line.split())

# %%
len(pos_seq)
# Out:
# 5101

# %%
f = open("combine_fasta.txt", "x")
f = open("combine_fasta.txt", "a")

i=1
for l in pos_seq:
  print(">",end='')
  f.write(">")
  j=str(i)
  f.write(j)
  f.write("\n")
  for k in l:
    p=str(k)
    f.write(p)
  #f.write(l2)
  f.write("\n")
  #print(i)
  #print(l2)
  i+=1
  
f.close()

# %%
neg = 'OutputNegative.txt'
neg_seq = []
with open(neg, 'r', encoding="utf-8",errors='ignore') as f:
    for line in f:
        neg_seq.append(line.split())

# %%
len(neg_seq)
# Out:
# 173829

# %%
f = open("neg_fasta.txt", "x")
f = open("neg_fasta.txt", "a")

i=6557
for l in neg_seq:
  print(">",end='')
  f.write(">")
  j=str(i)
  f.write(j)
  f.write("\n")
  for k in l:
    p=str(k)
    f.write(p)
  #f.write(l2)
  f.write("\n")
  #print(i)
  #print(l2)
  i+=1
  
f.close()
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ...
